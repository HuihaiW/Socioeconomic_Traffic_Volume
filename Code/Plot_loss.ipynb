# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv(r'../Weights_project/GAT_LSTM/train_validation_loss.csv')

# %%
df = df[['train_loss', 'val_loss']]

# %%
df.values
# Out:
# array([[0.21480957, 0.17734392],
#        [0.16802445, 0.18712862],
#        [0.14124476, 0.12614963],
#        ...,
#        [0.07526747, 0.07414257],
#        [0.07129379, 0.07138876],
#        [0.07891243, 0.09414877]])

# %%
plt.plot(df.values[0:50, 0], label='training loss')
plt.plot(df.values[0:50, 1], label='validation loss')
plt.legend()
